# %% [markdown]
# # Investigating the Data

# %%
from plot_fuse_results import (plot_results, get_merged_table, get_bohlin78)

# %% [markdown]
# # Get the data

# %% [markdown]
# ### data for Gordon09 extinction curve sightlines

# %%
data = get_merged_table()

# %% [markdown]
# ### data for Gordon09 comparision star sightlines

# %%
data_comp = get_merged_table(comp=True)

# %% [markdown]
# ### data for Bohlin 78 Copernicus sightlines

# %%
data_bohlin78 = get_bohlin78()

# %%
print(sorted(data.colnames))
# Out:
# ['AV', 'AV_runc', 'AV_sunc', 'AV_unc', 'C1', 'C1_unc', 'C2', 'C2_unc', 'C3', 'C3_unc', 'C4', 'C4_unc', 'CAV1', 'CAV1_runc', 'CAV1_sunc', 'CAV1_unc', 'CAV2', 'CAV2_runc', 'CAV2_sunc', 'CAV2_unc', 'CAV3', 'CAV3_runc', 'CAV3_sunc', 'CAV3_unc', 'CAV4', 'CAV4_runc', 'CAV4_sunc', 'CAV4_unc', 'Comparison', 'EBV', 'EBV_runc', 'EBV_sunc', 'EBV_unc', 'NH_AV', 'NH_AV_unc', 'NH_EBV', 'NH_EBV_unc', 'Name', 'RV', 'RV_runc', 'RV_sunc', 'RV_unc', 'SpType', 'V', 'bump_area', 'bump_area_unc', 'fh2', 'fh2_unc', 'gamma', 'gamma_runc', 'gamma_sunc', 'gamma_unc', 'hiref', 'logfh2', 'lognh', 'lognh2', 'lognh2_unc', 'lognhi', 'lognhi_unc', 'lognhtot', 'lognhtot_unc', 'nh', 'nh2', 'nh2_unc', 'nhi', 'nhi_unc', 'nhtot', 'nhtot_unc', 'x_o', 'x_o_runc', 'x_o_sunc', 'x_o_unc']

# %% [markdown]
# # FM90 params versus fraction H2

# %%
plot_results(data, 'fh2', 'CAV1')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ -------------------
#     0.6917515992993427 0.43522092780965377

# %%
plot_results(data, 'fh2', 'CAV2')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ --------------------
#     0.2895558924779918 -0.11664876174363302

# %%
plot_results(data, 'fh2', 'CAV3')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ------------------ ------------------
#     0.9139926926499604 0.6892447475196462

# %%
plot_results(data, 'fh2', 'CAV4')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                  c1
#     ------------------- -------------------
#     0.07289995300553767 0.16443570002626598

# %%
plot_results(data, 'fh2', 'x_o')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ----------------- --------------------
#     4.619300237893363 -0.09962246635308941

# %%
plot_results(data, 'fh2', 'gamma')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                c1
#     ----------------- ------------------
#     0.918474633573383 0.3677808928191338

# %%
plot_results(data, 'fh2', 'bump_area')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ------------------ ------------------
#     1.5220263856185368 0.6195619274879428

# %% [markdown]
# # FM90 parameters versus R(V)

# %%
plot_results(data, 'RV', 'CAV2', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ----------------- --------------------
#     0.591920037482462 -0.09951173781791672

# %%
plot_results(data, 'RV', 'CAV3', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ----------------- --------------------
#     2.172942196250374 -0.32618532265579975

# %%
plot_results(data, 'RV', 'CAV4', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ --------------------
#     0.2287319305063455 -0.03443886491625678

# %%
plot_results(data, 'RV', 'gamma', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ -------------------
#     0.9477701300718426 0.01879948869211456

# %%
plot_results(data, 'RV', 'x_o', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ----------------- ---------------------
#     4.618456877619077 -0.007221107105703529

# %%
plot_results(data, 'RV', 'bump_area', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ----------------- -------------------
#     3.362478764350241 -0.5059619429359289

# %% [markdown]
# # FM90 parameters in native form (E(lambda - V)/E(B-V)) versus R(V)

# %%
plot_results(data, 'RV', 'C2', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ --------------------
#     1.3756381089471983 -0.16284102365740777

# %%
plot_results(data, 'RV', 'C3', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                 c1
#     ----------------- --------------------
#     4.116111338516883 -0.18308072676205236

# %%
plot_results(data, 'RV', 'C4', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                   c1
#     ------------------ ---------------------
#     0.4270578981968661 -0.017760115123529065

# %%
plot_results(data, 'RV', 'gamma', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ -------------------
#     0.9477701300718426 0.01879948869211456

# %%
plot_results(data, 'RV', 'x_o', pxrange=[2.0,6.0])
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ----------------- ---------------------
#     4.618456877619077 -0.007221107105703529

# %% [markdown]
# # Some FM90 parameters versus A(V)

# %%
plot_results(data, 'AV', 'CAV4')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                   c1
#     ------------------- ---------------------
#     0.13688506084045338 -0.016052932688309065

# %% [markdown]
# # Random plots

# %%
plot_results(data, 'C3', 'C4')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                  c1
#     ------------------- --------------------
#     0.18637523313151946 0.051770082099270004
