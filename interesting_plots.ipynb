# %% [markdown]
# # Investigating the Data

# %%
from plot_fuse_results import (plot_results, get_merged_table, get_bohlin78)

# %% [markdown]
# # Get the data

# %% [markdown]
# ### data for Gordon09 extinction curve sightlines

# %%
data = get_merged_table()

# %% [markdown]
# ### data for Gordon09 comparision star sightlines

# %%
data_comp = get_merged_table(comp=True)

# %% [markdown]
# ### data for Bohlin 78 Copernicus sightlines

# %%
data_bohlin78 = get_bohlin78()

# %% [markdown]
# # Gas-to-A(V)

# %%
plot_results(data, 'AV', 'nhtot', pxrange=[0.0,3.5], pyrange=[0.0,0.8e22],
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                    c1
#     --------------------- ----------------------
#     6.146027690388303e+20 1.6257547137289866e+21

# %% [markdown]
# # Gas-to-E(B-V)

# %%
plot_results(data, 'EBV', 'nhtot', pyrange=[0.0,0.8e22],
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#                c0                    c1
#     ----------------------- --------------------
#     -1.0577794598444666e+20 7.06086915459092e+21

# %% [markdown]
# ## Gas-to-A(V) versus dust column

# %%
plot_results(data, 'AV', 'NH_AV', pyrange=[0.0,0.5e22],
            data_comp=data_comp,data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                      c1
#     ---------------------- -----------------------
#     2.4870805756447393e+21 -2.6705678298207892e+20

# %% [markdown]
# ## Gas-to-E(B-V) versus dust column

# %%
plot_results(data, 'EBV', 'NH_EBV', pyrange=[0.0,1.5e22],
            data_comp=data_comp,data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                    c1
#     --------------------- ----------------------
#     7.640567650338103e+21 -1.729940349140891e+21

# %% [markdown]
# # Gas-to-A(V) versus average grain size

# %%
plot_results(data, 'RV', 'NH_AV', pxrange=[2.5,6.0], pyrange=[0.0,0.5e22],
            data_comp=data_comp)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                     c1
#     ---------------------- ----------------------
#     3.3057795614626037e+21 -3.600261553381242e+20

# %% [markdown]
# # Gas-to-A(V) versus molecular fraction

# %%
plot_results(data, 'fh2', 'NH_AV', pxrange=[0.0,0.7], pyrange=[0.0,0.5e22],
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                     c1
#     ---------------------- ----------------------
#     2.3300684786191046e+21 -8.950095002272736e+20

# %% [markdown]
# # Gas-to-E(B-V) versus molecular fraction

# %%
plot_results(data, 'fh2', 'NH_EBV', pxrange=[0.0,0.7], pyrange=[0.0,1.5e22],
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#               c0                     c1
#     --------------------- -----------------------
#     7.856440844208518e+21 -3.8416651037289155e+21

# %% [markdown]
# # molecular fraction versus E(B-V) dust column

# %%
plot_results(data, 'EBV', 'fh2',
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                  c1
#     ------------------- -------------------
#     0.07117262949370143 0.41549437493926156

# %% [markdown]
# # molecular fraction versus A(V) dust column

# %%
plot_results(data, 'AV', 'fh2',
            data_comp=data_comp, data_bohlin=data_bohlin78)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                  c1
#     ------------------- -------------------
#     0.09357828273171521 0.10968555449344314

# %% [markdown]
# # molecular fraction versus average grain size

# %%
plot_results(data, 'RV', 'fh2', pxrange=[2.0,6.0],
            data_comp=data_comp)
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#              c0                   c1
#     ------------------- ----------------------
#     0.26853740714742264 -0.0055805444838674485

# %% [markdown]
# longitude versus rv and distance versus rv (and versus fh2)

# %% [markdown]
# COS FUV needs 2x10-13 ergs/blah blah

# %% [markdown]
# E140H for CO (maybe E140M), S/N 15...

# %% [markdown]
# E(B-V)/distance versus fH2.  Should also do A(V)/d.  Maybe n(H) as well.

# %%
plot_results(data, 'EBV', 'RV')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                  c1
#     ------------------ -------------------
#     3.5308447085457533 -0.4633824958454196

# %%
plot_results(data, 'AV', 'RV')
# Out:
# Model: Polynomial1D
# Inputs: ('x',)
# Outputs: ('y',)
# Model set size: 1
# Degree: 1
# Parameters:
#             c0                c1
#     ----------------- ------------------
#     2.666658527151499 0.4663356758664185
